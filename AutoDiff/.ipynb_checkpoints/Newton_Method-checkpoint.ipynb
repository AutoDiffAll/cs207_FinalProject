# %%
try:
    from variables import Variable
except:
    from AutoDiff.variables import Variable
try:
    from vectorize_func import vectorize_variable
except:
    from AutoDiff.vectorize_func import vectorize_variable
try:
    import AD_numpy as anp
except:
    import AutoDiff.AD_numpy as anp
import numpy as np

# %%
#@vectorize_variable
#def vec_fn(x, y):
#    f1 = anp.cos(x) + anp.sin(y)
#    f2 = x**2 + y**2
#    return np.array([f1,f2])

# %%
def newton_method_scalar(function, list_variables, threshold, max_iter, verbose=True):
    nums_iteration = 1
    key_val_dict = {}
    while True:
        # This line is the only difference between two newton_method_scalar functions
        function = x**2 + y**2
        value_f = function.val
        for var in list_variables:
            var.val = var.val - value_f/function.der[var.name]
            key_val_dict[var] = var.val
        if verbose is True:
            print(f'Iteration at {nums_iteration}, at {list(key_val_dict.values())} ')
        if abs(value_f) <= threshold:
            break
        if nums_iteration == 10:
            break
        nums_iteration +=1

# %%
x = Variable('x', 3)
y = Variable('y', 2)
f_x_y = x**2 + y**2
list_var = [x, y]
newton_method_scalar(f_x_y, list_var, 1e-6, 50, verbose=True)
# Out:
# Iteration at 1, at [0.8333333333333335, -1.25]
# Variable name: f(f(x),f(y)), Value: 13, Derivatives: {'y': 4, 'x': 6}
# 13
# Iteration at 2, at [-0.520833333333333, -0.3472222222222221]
# Variable name: f(f(x),f(y)), Value: 2.2569444444444446, Derivatives: {'y': -2.5, 'x': 1.666666666666667}
# 2.2569444444444446
# Iteration at 3, at [-0.14467592592592576, 0.21701388888888873]
# Variable name: f(f(x),f(y)), Value: 0.391830632716049, Derivatives: {'y': -0.6944444444444442, 'x': -1.041666666666666}
# 0.391830632716049
# Iteration at 4, at [0.09042245370370375, 0.06028163580246912]
# Variable name: f(f(x),f(y)), Value: 0.0680261515132029, Derivatives: {'y': 0.43402777777777746, 'x': -0.2893518518518515}
# 0.0680261515132029
# Iteration at 5, at [0.025117348251028848, -0.0376760223765433]
# Variable name: f(f(x),f(y)), Value: 0.011810095748819974, Derivatives: {'y': 0.12056327160493824, 'x': 0.1808449074074075}
# 0.011810095748819974
# Iteration at 6, at [-0.01569834265689307, -0.010465561771262042]
# Variable name: f(f(x),f(y)), Value: 0.0020503638452812533, Derivatives: {'y': -0.0753520447530866, 'x': 0.050234696502057696}
# 0.0020503638452812533
# Iteration at 7, at [-0.004360650738025858, 0.006540976107038788]
# Variable name: f(f(x),f(y)), Value: 0.0003559659453613301, Derivatives: {'y': -0.020931123542524084, 'x': -0.03139668531378614}
# 0.0003559659453613301
# Iteration at 8, at [0.002725406711266163, 0.0018169378075107746]
# Variable name: f(f(x),f(y)), Value: 6.179964329189776e-05, Derivatives: {'y': 0.013081952214077576, 'x': -0.008721301476051716}
# 6.179964329189776e-05
# Iteration at 9, at [0.0007570574197961568, -0.0011355861296942354]
# Variable name: f(f(x),f(y)), Value: 1.0729104738176702e-05, Derivatives: {'y': 0.0036338756150215493, 'x': 0.005450813422532326}
# 1.0729104738176702e-05
# Iteration at 10, at [-0.0004731608873725984, -0.0003154405915817322]
# Variable name: f(f(x),f(y)), Value: 1.8626917948223473e-06, Derivatives: {'y': -0.002271172259388471, 'x': 0.0015141148395923136}
# 1.8626917948223473e-06

# %%
def newton_method_scalar(function, list_variables, threshold, max_iter, verbose=True):
    
    nums_iteration = 1
    key_val_dict = {}
    while True:
        value_f = function.val
        for var in list_variables:
            var.val = var.val - value_f/function.der[var.name]
            key_val_dict[var] = var.val
        if verbose is True:
            print(f'Iteration at {nums_iteration}, at {list(key_val_dict.values())} ')
        if abs(value_f) <= threshold:
            break
        if nums_iteration >= max_iter:
            break
        nums_iteration +=1

# %%
def newton_method_scalar(fn, initial_val, threshold, max_iter, verbose=True):
    
    # create initial variables
    # right now we only test with the 26 alphabets
    from string import ascii_lowercase
    import pandas as pd
    
    name_ls = iter(ascii_lowercase)
    
    # create initial variables
    var_names = []
    var = []
    for i in initial_val:
        name = next(name_ls)
        var.append(Variable(name, i))
        var_names.append(name)
    
    val = np.array(initial_val)
    nums_iteration = 1
    while True:
        val_new = val - fn(*val) / pd.DataFrame(fn(*var).der, index=[0]).values[0]
        
        # recreate new variables with new values
        var = []
        for i, v in enumerate(val_new):
            var.append(Variable(var_names[i], v))
            
        # print iteration output
        if verbose is True:
            print(f'Iteration at {nums_iteration}, at {val_new} ')
            
        # threshold stopping condition 
        if np.sqrt(np.sum((val_new - val)**2)) < threshold:
            break
        print(pd.DataFrame(fn(*var).der, index=[0]).values[0])
        print(var)
        # iteration stopping condition
        if nums_iteration >= max_iter:
            break
        nums_iteration +=1
        val = val_new

# %%
f = lambda x, y, z: (x-2)**2 + (y-1)**2 + (z+3)**2

# %%
newton_method_scalar(f, [1, 2, -2], 1e-6, 50, verbose=True)
# Out:
# Iteration at 1, at [ 2.5  0.5 -3.5]
# [ 1. -1. -1.]
# [Variable name: a, Value: 2.5, Derivatives: {'a': 1}, Variable name: b, Value: 0.5, Derivatives: {'b': 1}, Variable name: c, Value: -3.5, Derivatives: {'c': 1}]
# Iteration at 2, at [ 1.75  1.25 -2.75]
# [-0.5  0.5  0.5]
# [Variable name: a, Value: 1.75, Derivatives: {'a': 1}, Variable name: b, Value: 1.25, Derivatives: {'b': 1}, Variable name: c, Value: -2.75, Derivatives: {'c': 1}]
# Iteration at 3, at [ 2.125  0.875 -3.125]
# [ 0.25 -0.25 -0.25]
# [Variable name: a, Value: 2.125, Derivatives: {'a': 1}, Variable name: b, Value: 0.875, Derivatives: {'b': 1}, Variable name: c, Value: -3.125, Derivatives: {'c': 1}]
# Iteration at 4, at [ 1.9375  1.0625 -2.9375]
# [-0.125  0.125  0.125]
# [Variable name: a, Value: 1.9375, Derivatives: {'a': 1}, Variable name: b, Value: 1.0625, Derivatives: {'b': 1}, Variable name: c, Value: -2.9375, Derivatives: {'c': 1}]
# Iteration at 5, at [ 2.03125  0.96875 -3.03125]
# [ 0.0625 -0.0625 -0.0625]
# [Variable name: a, Value: 2.03125, Derivatives: {'a': 1}, Variable name: b, Value: 0.96875, Derivatives: {'b': 1}, Variable name: c, Value: -3.03125, Derivatives: {'c': 1}]
# Iteration at 6, at [ 1.984375  1.015625 -2.984375]
# [-0.03125  0.03125  0.03125]
# [Variable name: a, Value: 1.984375, Derivatives: {'a': 1}, Variable name: b, Value: 1.015625, Derivatives: {'b': 1}, Variable name: c, Value: -2.984375, Derivatives: {'c': 1}]
# Iteration at 7, at [ 2.0078125  0.9921875 -3.0078125]
# [ 0.015625 -0.015625 -0.015625]
# [Variable name: a, Value: 2.0078125, Derivatives: {'a': 1}, Variable name: b, Value: 0.9921875, Derivatives: {'b': 1}, Variable name: c, Value: -3.0078125, Derivatives: {'c': 1}]
# Iteration at 8, at [ 1.99609375  1.00390625 -2.99609375]
# [-0.0078125  0.0078125  0.0078125]
# [Variable name: a, Value: 1.99609375, Derivatives: {'a': 1}, Variable name: b, Value: 1.00390625, Derivatives: {'b': 1}, Variable name: c, Value: -2.99609375, Derivatives: {'c': 1}]
# Iteration at 9, at [ 2.00195312  0.99804688 -3.00195312]
# [ 0.00390625 -0.00390625 -0.00390625]
# [Variable name: a, Value: 2.001953125, Derivatives: {'a': 1}, Variable name: b, Value: 0.998046875, Derivatives: {'b': 1}, Variable name: c, Value: -3.001953125, Derivatives: {'c': 1}]
# Iteration at 10, at [ 1.99902344  1.00097656 -2.99902344]
# [-0.00195312  0.00195312  0.00195312]
# [Variable name: a, Value: 1.9990234375, Derivatives: {'a': 1}, Variable name: b, Value: 1.0009765625, Derivatives: {'b': 1}, Variable name: c, Value: -2.9990234375, Derivatives: {'c': 1}]
# Iteration at 11, at [ 2.00048828  0.99951172 -3.00048828]
# [ 0.00097656 -0.00097656 -0.00097656]
# [Variable name: a, Value: 2.00048828125, Derivatives: {'a': 1}, Variable name: b, Value: 0.99951171875, Derivatives: {'b': 1}, Variable name: c, Value: -3.00048828125, Derivatives: {'c': 1}]
# Iteration at 12, at [ 1.99975586  1.00024414 -2.99975586]
# [-0.00048828  0.00048828  0.00048828]
# [Variable name: a, Value: 1.999755859375, Derivatives: {'a': 1}, Variable name: b, Value: 1.000244140625, Derivatives: {'b': 1}, Variable name: c, Value: -2.999755859375, Derivatives: {'c': 1}]
# Iteration at 13, at [ 2.00012207  0.99987793 -3.00012207]
# [ 0.00024414 -0.00024414 -0.00024414]
# [Variable name: a, Value: 2.0001220703125, Derivatives: {'a': 1}, Variable name: b, Value: 0.9998779296875, Derivatives: {'b': 1}, Variable name: c, Value: -3.0001220703125, Derivatives: {'c': 1}]
# Iteration at 14, at [ 1.99993896  1.00006104 -2.99993896]
# [-0.00012207  0.00012207  0.00012207]
# [Variable name: a, Value: 1.99993896484375, Derivatives: {'a': 1}, Variable name: b, Value: 1.00006103515625, Derivatives: {'b': 1}, Variable name: c, Value: -2.99993896484375, Derivatives: {'c': 1}]
# Iteration at 15, at [ 2.00003052  0.99996948 -3.00003052]
# [ 6.10351562e-05 -6.10351562e-05 -6.10351562e-05]
# [Variable name: a, Value: 2.000030517578125, Derivatives: {'a': 1}, Variable name: b, Value: 0.999969482421875, Derivatives: {'b': 1}, Variable name: c, Value: -3.000030517578125, Derivatives: {'c': 1}]
# Iteration at 16, at [ 1.99998474  1.00001526 -2.99998474]
# [-3.05175781e-05  3.05175781e-05  3.05175781e-05]
# [Variable name: a, Value: 1.9999847412109375, Derivatives: {'a': 1}, Variable name: b, Value: 1.0000152587890625, Derivatives: {'b': 1}, Variable name: c, Value: -2.9999847412109375, Derivatives: {'c': 1}]
# Iteration at 17, at [ 2.00000763  0.99999237 -3.00000763]
# [ 1.52587891e-05 -1.52587891e-05 -1.52587891e-05]
# [Variable name: a, Value: 2.0000076293945312, Derivatives: {'a': 1}, Variable name: b, Value: 0.9999923706054688, Derivatives: {'b': 1}, Variable name: c, Value: -3.0000076293945312, Derivatives: {'c': 1}]
# Iteration at 18, at [ 1.99999619  1.00000381 -2.99999619]
# [-7.62939453e-06  7.62939453e-06  7.62939453e-06]
# [Variable name: a, Value: 1.9999961853027344, Derivatives: {'a': 1}, Variable name: b, Value: 1.0000038146972656, Derivatives: {'b': 1}, Variable name: c, Value: -2.9999961853027344, Derivatives: {'c': 1}]
# Iteration at 19, at [ 2.00000191  0.99999809 -3.00000191]
# [ 3.81469727e-06 -3.81469727e-06 -3.81469727e-06]
# [Variable name: a, Value: 2.000001907348633, Derivatives: {'a': 1}, Variable name: b, Value: 0.9999980926513672, Derivatives: {'b': 1}, Variable name: c, Value: -3.000001907348633, Derivatives: {'c': 1}]
# Iteration at 20, at [ 1.99999905  1.00000095 -2.99999905]
# [-1.90734863e-06  1.90734863e-06  1.90734863e-06]
# [Variable name: a, Value: 1.9999990463256836, Derivatives: {'a': 1}, Variable name: b, Value: 1.0000009536743164, Derivatives: {'b': 1}, Variable name: c, Value: -2.9999990463256836, Derivatives: {'c': 1}]
# Iteration at 21, at [ 2.00000048  0.99999952 -3.00000048]
# [ 9.53674316e-07 -9.53674316e-07 -9.53674316e-07]
# [Variable name: a, Value: 2.000000476837158, Derivatives: {'a': 1}, Variable name: b, Value: 0.9999995231628418, Derivatives: {'b': 1}, Variable name: c, Value: -3.000000476837158, Derivatives: {'c': 1}]
# Iteration at 22, at [ 1.99999976  1.00000024 -2.99999976]
# [-4.76837158e-07  4.76837158e-07  4.76837158e-07]
# [Variable name: a, Value: 1.999999761581421, Derivatives: {'a': 1}, Variable name: b, Value: 1.000000238418579, Derivatives: {'b': 1}, Variable name: c, Value: -2.999999761581421, Derivatives: {'c': 1}]
# Iteration at 23, at [ 2.00000012  0.99999988 -3.00000012]
